# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset/face_encodings.csv')

# %%
class_dist = df.groupby(['128']).nunique()['0']
class_dist
# Out:
# 128
# aca          23
# adi           8
# andre         5
# arifin       11
# aris        119
# artha        13
# budi         30
# cici         34
# dadang_h     27
# eni          34
# entis        23
# esti         10
# evi          58
# fahrul        8
# gina         29
# gita         31
# hafis        51
# hanif         1
# hendar       59
# hendi         7
# heri         46
# ilham         1
# ipin          2
# irfan         1
# jony        141
# kuskus       25
# mery          4
# mulyana       8
# novan       115
# oka          12
# others       33
# rendra       13
# rian        178
# rizky        41
# robi         21
# tatang       32
# taufik_h     40
# triya       253
# ulfah        21
# yanto        55
# Name: 0, dtype: int64

# %%
plt.plot(class_dist)

# %% [markdown]
# ### Dimentionality Reduction u/ Visualisasi
# ada 128 feature yang digunakan u/ klasifikasi (128 titik landmark wajah). Tetapi tidak mungkin di-visualisasikan dengan 128 dimensi. Jadi kita reduksi menjadi 3 dimensi dengan PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
V = pca.fit_transform(df.drop('128', axis=1))

pca_df = pd.DataFrame(V, columns=['pc_1', 'pc_2', 'pc_3'])
pca_df['name'] = df['128']
pca_df
# Out:
# 0         ilham
# 1       mulyana
# 2       mulyana
# 3       mulyana
# 4       mulyana
# 5       mulyana
# 6       mulyana
# 7       mulyana
# 8       mulyana
# 9        hendar
# 10       hendar
# 11       hendar
# 12       hendar
# 13       hendar
# 14       hendar
# 15       hendar
# 16       hendar
# 17       hendar
# 18       hendar
# 19       hendar
# 20       hendar
# 21       hendar
# 22       hendar
# 23       hendar
# 24       hendar
# 25       hendar
# 26       hendar
# 27       hendar
# 28       hendar
# 29       hendar
#          ...
# 1593       heri
# 1594       heri
# 1595       heri
# 1596       heri
# 1597       heri
# 1598       heri
# 1599       heri
# 1600       heri
# 1601       heri
# 1602       heri
# 1603       heri
# 1604       heri
# 1605       heri
# 1606       heri
# 1607       heri
# 1608       heri
# 1609       heri
# 1610       heri
# 1611       heri
# 1612       heri
# 1613       esti
# 1614       esti
# 1615       esti
# 1616       esti
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline  


fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(111, projection='3d') 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3 component PCA', fontsize = 20)
targets = df['128']
colors = cm.rainbow(np.linspace(0, 1, len(targets)))
# for target, color in zip(targets,colors):
for target in targets:
    indicesToKeep = pca_df['name'] == target
    ax.scatter(pca_df.loc[indicesToKeep, 'pc_1']
               , pca_df.loc[indicesToKeep, 'pc_2']
               , pca_df.loc[indicesToKeep, 'pc_3']
               
               , s = 50)
ax.legend(targets)
ax.grid()
